# %%
import numpy as np
import matplotlib.pyplot as plt
import sncosmo
from astropy.table import Table
import _sncosmo_ported_model as sn91bg

# %%
source=sn91bg.SN91bgSource()
model=sncosmo.Model(source=source)
#print(model)

# %%
phase=np.arange(-13,101,1)
wave=np.arange(1000,12010,10)
plt.plot(phase, source.flux(phase, 5645))

# %%
data=Table.read('../tests/sn91bg_50003.csv')
result, fitted_model = sncosmo.fit_lc(data, model,['z','t0','amplitude', 'stretch', 'color'],
                                      bounds={'z': (0.01, .1)})
sncosmo.plot_lc(data,model=fitted_model,errors=result.errors)
print(result.chisq/result.ndof)
# Out:
# 1.0024765845207326
